# %%
import torch
from torchvision import transforms, datasets, models
import torch.nn as nn
import numpy as np
import cv2
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
train_data_path = 'data/train'
val_data_path = 'data/validation'

# Define transforms for the training data and testing data
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224), # rescale the image
        transforms.RandomHorizontalFlip(), # randomly flip image horizontally
        transforms.RandomRotation(10), # randomly rotate image
        transforms.ToTensor(), # convert the image to a Tensor
        transforms.Normalize([0.485, 0.456, 0.406], # normalize image for pre-trained model
                                [0.229, 0.224, 0.225])
    ]),
    'validation': transforms.Compose([
        transforms.Resize(256), # rescale the image
        transforms.CenterCrop(224), # crop image
        transforms.ToTensor(), # convert the image to a Tensor
        transforms.Normalize([0.485, 0.456, 0.406], # normalize image for pre-trained model
                                [0.229, 0.224, 0.225])
    ]),
}

train_dataset = datasets.ImageFolder(train_data_path, transform=data_transforms['train'])
val_dataset = datasets.ImageFolder(val_data_path, transform=data_transforms['validation'])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size = 32, shuffle=True)
# Dataloader iterators, make sure to shuffle

print(train_dataset.class_to_idx)
# Out:
# {'damage': 0, 'no_damage': 1}

# %%
import torch.nn as nn
import torchvision.models as models

class SEModule(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEModule, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channels // reduction, channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y

def add_se_module(resnet_model):
    for child_name, child in resnet_model.named_children():
        if isinstance(child, nn.Sequential):  # Checking if the current child is a Sequential module
            for block_name, block in child.named_children():
                if block.downsample is not None:
                    block.add_module("se_module", SEModule(block.downsample[0].out_channels))
                else:
                    block.add_module("se_module", SEModule(block.conv2.out_channels))
    return resnet_model


model = models.resnet101(pretrained=True)
model = add_se_module(model)

# Freeze model weights
for param in model.parameters():
    param.requires_grad = False
#五分类结果预测



model.fc = nn.Sequential(
    nn.Linear(2048, 512),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(512, 2),
    nn.LogSoftmax(dim=1)
)

# If GPU is available, use GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define Optimizer and Loss Function
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.001)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=1024, out_features=64, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=64, out_features=1024, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=2048, out_features=128, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=128, out_features=2048, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (se_module): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=512, out_features=32, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=32, out_features=512, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=2, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
# Train the model
epochs = 50
for epoch in range(epochs):
    train_loss = 0.0
    val_loss = 0.0
    accuracy = 0.0
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # Move tensors to GPU if CUDA is available
        data, target = data.to(device), target.to(device)
        # Clear the gradients
        optimizer.zero_grad()
        # Forward pass
        output = model(data)
        # Calculate the batch loss
        loss = criterion(output, target)
        # Backward pass
        loss.backward()
        # Perform optimization
        optimizer.step()
        # Update train loss
        train_loss += loss.item()*data.size(0)
    # Calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    # Print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch+1, 
        train_loss
        ))
    # Validation
    model.eval()
    for batch_idx, (data, target) in enumerate(val_loader):
        # Move tensors to GPU if CUDA is available
        data, target = data.to(device), target.to(device)
        # Forward pass
        output = model(data)
        # Calculate the batch loss
        loss = criterion(output, target)
        # Update average validation loss 
        val_loss += loss.item()*data.size(0)
        # Calculate validation accuracy
        _, pred = torch.max(output, dim=1)
        correct_tensor = pred.eq(target.data.view_as(pred))
        accuracy += torch.mean(correct_tensor.type(torch.FloatTensor))
    # Calculate average losses
    val_loss = val_loss/len(val_loader.dataset)
    accuracy = accuracy/len(val_loader)
    # Print training/validation statistics 
    print('Epoch: {} \tValidation Loss: {:.6f} \tAccuracy: {:.2f}%'.format(
        epoch+1, 
        val_loss,
        accuracy*100
        ))
    # Save model
    if accuracy > 0.94:
        torch.save(model.state_dict(), 'model.pt')
        break
# Out:
# Epoch: 1 	Training Loss: 0.176194
# Epoch: 1 	Validation Loss: 0.173159 	Accuracy: 92.11%
# Epoch: 2 	Training Loss: 0.169192
# Epoch: 2 	Validation Loss: 0.115808 	Accuracy: 95.34%

# %%
# Test the model
test_data_path = 'data/test'
test_dataset = datasets.ImageFolder(test_data_path, transform=data_transforms['validation'])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = 32, shuffle=True)
model.state_dict(torch.load('model.pt'))
model.eval()
accuracy = 0.0
error_count = 0
for batch_idx, (data, target) in enumerate(test_loader):
    data, target = data.to(device), target.to(device)
    output = model(data)
    _, pred = torch.max(output, dim=1)
    for i in range(len(target)):
        print(test_loader.dataset.imgs[i][0].split('/')[-1],
              "Pre Res:","damage" if pred[i] == 1 else "no_damage", 
              "Actul Res:","damage" if target[i] == 1 else "no_damage")
        if pred[i] != target[i]:
            error_count += 1
            print("Error Prediction")
    
    correct_tensor = pred.eq(target.data.view_as(pred))
    accuracy += torch.mean(correct_tensor.type(torch.FloatTensor))
accuracy = accuracy/len(test_loader)
error_rate = error_count/len(test_loader.dataset)
print('Test Accuracy: {:.2f}%'.format(accuracy*100), "Error Rate: {:.2f}%".format(error_rate*100))
# Out:
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# ...
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.67021_30.218049.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.672914_30.215835.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.682517_29.782388.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.662984_30.209982.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6654_30.140094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.666735_30.201598999999998.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.667964_30.143383.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669493_30.217792.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.669804_30.221032.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.669949_30.223813.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.67021_30.218049.jpeg Pre Res: damage Actul Res: no_damage
# Error Prediction
# test\damage\-93.671616_30.223004.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.672914_30.215835.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.674148_30.215922999999997.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.67773199999999_30.135996000000002.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.678446_30.205085999999998.jpeg Pre Res: no_damage Actul Res: damage
# Error Prediction
# test\damage\-93.682517_29.782388.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.71154399999999_29.767281.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.72404300000001_30.075196000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.548123_30.900623.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.560128_30.894917.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.578271_30.779923999999998.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.590598_30.694956.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.604017_30.793719.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.6141_30.754263.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.618483_30.730039.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65613_30.076164000000002.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.658785_30.206929.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659161_30.202384999999996.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.65936500000001_30.138793.jpeg Pre Res: damage Actul Res: damage
# test\damage\-93.659805_30.138094.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.660431_30.20485.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.661241_30.212164.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.66200400000001_30.201602.jpeg Pre Res: no_damage Actul Res: no_damage
# test\damage\-93.662444_30.201583000000003.jpeg Pre Res: no_damage Actul Res: no_damage
# Test Accuracy: 96.03% Error Rate: 4.00%

# %%
#define Grad-CAM
class GradCAM:
    def __init__(self, model, layer_name):
        self.model = model
        self.layer_name = layer_name
        self.target_layer = dict([*self.model.named_modules()])[layer_name]
        self.gradients = None
        self.target_value = None  # Added
        self.target_layer.register_forward_hook(self.save_gradient)
        self.target_layer.register_forward_hook(self.save_value)  # Added

    def save_gradient(self, module, input, output):
        self.gradients = output

    def save_value(self, module, input, output):  # Added
        self.target_value = output

    def __call__(self, inputs, index=None):
        outputs = self.model(inputs)
        if index is None:
            index = torch.argmax(outputs, 1)
        one_hot = torch.zeros((1, outputs.size()[-1]), dtype=torch.float32)
        one_hot[0][index] = 1
        one_hot = one_hot.requires_grad_().to(device)
        one_hot = torch.sum(one_hot * outputs)
        one_hot.backward(retain_graph=True)
        grad_values = self.gradients[0].cpu().data.numpy()
        target = self.target_value[0].cpu().data.numpy()  # Modified
        weights = np.mean(grad_values, axis=(1, 2))
        cam = np.zeros(target.shape[1:], dtype=np.float32)
        for i, w in enumerate(weights):
            cam += w * target[i, :, :]
        cam = np.maximum(cam, 0)
        cam = cv2.resize(cam, (224, 224))
        cam = cam - np.min(cam)
        cam = cam / np.max(cam)
        return cam
class DamgeScore:
    def __init__(self, model,layer_name):
        self.grad_cam = GradCAM(model, layer_name)
    def score(self, image_tensor):
        cam = self.grad_cam(image_tensor)
        damge_score = np.mean(cam)
        return damge_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
damge_score = DamgeScore(model, 'layer4')
grad_cam = GradCAM(model, 'layer4')

# 4. visualize
def visualize(image_path, cam):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))  # resize the image to (224,224,3)
    img = np.float32(img) / 255
    heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap + np.float32(img)
    cam = cam / np.max(cam)
    return cam

'''
# visualize all test images and save in outputs folder
for batch_idx, (data, target) in enumerate(test_loader):
    data, target = data.to(device), target.to(device)
    output = model(data)
    _, pred = torch.max(output, dim=1)
    for i in range(len(target)):
        img_path = test_loader.dataset.imgs[i][0]
        print(img_path)
        cam = grad_cam(data[i].unsqueeze(0), target[i])
        cam = cv2.resize(cam, (224, 224))
        cam = visualize(img_path, cam)
        score = damge_score.score(data[i].unsqueeze(0))
        plt.figure()
        plt.subplot(121)
        plt.imshow(plt.imread(img_path))
        plt.subplot(122)
        plt.imshow(cam)
        plt.title("Damage Score: {:.2f}".format(score))
        plt.show()
        #保存图片到本地outputs文件夹
        plt.imsave('outputs\\' + img_path.split('\\')[-1], cam)
'''
#visualize one image
score = []
for img, label in test_loader:
    if label[0] == 0:
        img = img.requires_grad_().to(device)  # Move img to the appropriate device
        cam = grad_cam(img)
        score = damge_score.score(img)

        vis = visualize(test_dataset.imgs[0][0], cam)
        plt.figure()
        plt.subplot(121)
        plt.imshow(plt.imread(test_dataset.imgs[0][0]))
        plt.subplot(122)
        plt.imshow(vis)
        plt.title("Damage Score: {:.2f}".format(score))
        plt.show()
        break
